# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %%
whale_returns = pd.read_csv('/Users/mihneaasandului/Downloads/whale_returns.csv', index_col='Date', parse_dates=True)

# Reading the algo_returns.csv file with 'Date' as the index
algo_returns = pd.read_csv('/Users/mihneaasandului/Downloads/algo_returns.csv', index_col='Date', parse_dates=True)

# Reading the sp500_history.csv file, parsing 'Date' with a specific format, and setting it as the index
sp500 = pd.read_csv('/Users/mihneaasandului/Downloads/sp500_history.csv', parse_dates=['Date'], date_parser=lambda x: pd.to_datetime(x, format='%d-%b-%y'))
sp500.set_index('Date', inplace=True)

# Processing monetary values in the sp500 DataFrame, if necessary
if 'Price' in sp500.columns:
    sp500['Price'] = sp500['Price'].replace('[\$,]', '', regex=True).astype(float)

# Optional: Display the first few rows of each DataFrame to verify the data
print("Whale Returns:")
print(whale_returns.head())
print("\nAlgo Returns:")
print(algo_returns.head())
print("\nS&P 500 History:")
print(sp500.head())
# Out:
# Whale Returns:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
#
# Algo Returns:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN
#
# S&P 500 History:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06
# /var/folders/_7/z362cyrd65v3y2zk7bkxtnw80000gn/T/ipykernel_3900/124126036.py:7: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   sp500 = pd.read_csv('/Users/mihneaasandului/Downloads/sp500_history.csv', parse_dates=['Date'], date_parser=lambda x: pd.to_datetime(x, format='%d-%b-%y'))

# %%
type(whale_returns.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
whale_returns = whale_returns.sort_index()
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
### Determine % of nulls in whale returns
whale_returns.isnull().mean() * 100
# Out:
# SOROS FUND MANAGEMENT LLC      0.09434
# PAULSON & CO.INC.              0.09434
# TIGER GLOBAL MANAGEMENT LLC    0.09434
# BERKSHIRE HATHAWAY INC         0.09434
# dtype: float64

# %%
# Dropping nulls in whale returns
whale_returns.dropna(inplace = True)
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
# Reading algorithmic returns
algo_returns = algo_returns.sort_index()
algo_returns.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Dropping nulls for algorithmic returns
algo_returns.dropna(inplace=True)
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
# Read S&P Closing prices
sp500 = sp500.sort_index()
sp500.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
#Check the data type
sp500.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Removing $$ signs
sp500["Close"] = sp500["Close"].str.replace("$", "")
sp500["Close"] = sp500["Close"].str.replace(",", "")
sp500["Close"] = sp500["Close"].astype("float")

# %%
sp500.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Daily returns in SP 500
daily_returns_sp500 = sp500.pct_change()
daily_returns_sp500.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
#Dropping nulls
daily_returns_sp500.dropna(inplace=True)
daily_returns_sp500.isnull().sum()
daily_returns_sp500.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename "close" column to be specific with portfolio
daily_returns_sp500.columns = ["SP500"]
daily_returns_sp500.head()
# Out:
#                SP500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Use the concat function to concat Dataframes: Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
joined_data_columns = pd.concat([whale_returns, algo_returns, daily_returns_sp500], axis="columns", join= "inner")
joined_data_columns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN -0.008158
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
#
#               Algo 2     SP500
# Date
# 2015-03-02  0.003200  0.006125
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# 2015-03-06 -0.011460 -0.014174

# %%
# Plot daily returns of all portfolios
# daily_returns_all = joined_data_columns.pct_change()
joined_data_columns.plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Date'>

# %%
# Does any portfolio outperform the S&P 500?
print("Berkshire Hathaway, Soros Fund Management, and Algo 2 all outperformed the SP Closing Price at one point in the data set")
# Out:
# Berkshire Hathaway, Soros Fund Management, and Algo 2 all outperformed the SP Closing Price at one point in the data set

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + joined_data_columns).cumprod()
# Plot cumulative returns
cumulative_returns.plot(figsize=(15,15))
# Out:
# <Axes: xlabel='Date'>

# %%
# Plot the box portfolio for each
print("Daily Returns for SP 500 Portfolio")
daily_returns_sp500.plot(kind="box")
# Out:
# Daily Returns for SP 500 Portfolio
# <Axes: >

# %%
dr_algo = algo_returns.pct_change()
dr_whale = whale_returns.pct_change()

combined_returns_part1 = pd.concat([dr_algo, dr_whale, daily_returns_sp500], axis="columns", join="inner")
combined_returns_part1
# Out:
#                Algo 1    Algo 2  SOROS FUND MANAGEMENT LLC  \
# Date
# 2015-03-02 -21.450071 -8.157548                        NaN
# 2015-03-03  -0.761929 -1.296713                        NaN
# 2015-03-04   3.422374 -3.544766                  -2.762070
# 2015-03-05  -0.888803  0.789231                   0.800968
# 2015-03-06   4.190043 -3.650914                  -2.968465
# ...               ...       ...                        ...
# 2019-04-16   0.603391 -1.634218                  -2.898341
# 2019-04-17   0.483294 -2.803170                  -2.073108
# 2019-04-18  -0.942926 -0.764890                  -1.499843
# 2019-04-22  -2.150780  0.574781                  -2.785826
# 2019-04-23   6.345216 -5.970574                  -3.771893
#
#             PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# Date
# 2015-03-02                 NaN                          NaN
# 2015-03-03                 NaN                          NaN
# 2015-03-04           -1.650792                     4.113646
# 2015-03-05            0.257544                    -1.929234
# 2015-03-06           -1.876837                    -4.601872
# ...                        ...                          ...
# 2019-04-16           -1.335693                    -3.088322
# 2019-04-17          -17.661104                     4.306537
# 2019-04-18           -1.188925                    -1.131886
# 2019-04-22           -7.001458                    -7.259521
# 2019-04-23           -1.475216                    -2.777848
#
#             BERKSHIRE HATHAWAY INC     SP500
# Date
# 2015-03-02                     NaN  0.006125
# 2015-03-03                     NaN -0.004539
# 2015-03-04               -1.641381 -0.004389
# 2015-03-05                0.596558  0.001196
# 2015-03-06               -2.947282 -0.014174
# ...                            ...       ...
# 2019-04-16               -1.079744  0.000509
# 2019-04-17                2.851033 -0.002274
# 2019-04-18               -0.405345  0.001579
# 2019-04-22               -1.567709  0.001012
# 2019-04-23              -13.206260  0.008841
#
# [1044 rows x 7 columns]

# %%
# Plot the box portfolio for each
print("Daily Returns for Algo Portfolio")
dr_algo.plot(kind="box")
# Out:
# Daily Returns for Algo Portfolio
# <Axes: >

# %%
# Plot the box portfolio for each
print("Daily Returns for Whale Portfolio")
dr_whale.plot(kind="box", figsize=(15,5))
# Out:
# Daily Returns for Whale Portfolio
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 # Plot the box portfolio for each
#       2 print("Daily Returns for Whale Portfolio")
# ----> 3 dr_whale.plot(kind="box", figsize=(15,5))
#
# NameError: name 'dr_whale' is not defined

# %%
# Check for NaNs in the DataFrame
print(whale_returns.isna().sum())

# Check for infinite values
print(whale_returns.isin([np.inf, -np.inf]).sum())
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
# Plot all box portfolios
joined_data_columns.plot(kind="box")
# Out:
# <Axes: >

# %%
# Standard deviation for all portfolios
daily_std_all = joined_data_columns.std()
daily_std_all.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007621
# dtype: float64

# %%
# Calculating the stock with most risk by putting them in descending order
daily_std_all = daily_std_all.sort_values(ascending=False)
daily_std_all.head(10)
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# SP500                          0.008551
# Algo 2                         0.008339
# SOROS FUND MANAGEMENT LLC      0.007895
# Algo 1                         0.007621
# PAULSON & CO.INC.              0.007023
# dtype: float64

# %%
# Which portfolio is riskiest?
print("Which portfolio is riskiest?")
print("Berkshire Hathaway, INC")
# Out:
# Which portfolio is riskiest?
# Berkshire Hathaway, INC

# %%
# Caclulate annualized standard deviation
annualized_std_all = daily_std_all * np.sqrt(252)
annualized_std_all.head()
# Out:
# BERKSHIRE HATHAWAY INC         0.205077
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# SP500                          0.135751
# Algo 2                         0.132374
# SOROS FUND MANAGEMENT LLC      0.125335
# dtype: float64

# %%
# Calculate and plot the rolling standard deviation for all portfolios using a 21 day window
joined_data_columns.rolling(window=21).std().plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Date'>

# %%
# Calculate and plot the correlation between each stock to determine which portfolios may mimick the S&P 500.
joined_data_columns.columns = ["SOROS", "PAULSON & CO", "TIGER GLOBAL", "BERK HATH", "ALGO 1", "ALGO 2", "SP500"]
correlation = joined_data_columns.corr()
correlation.style.background_gradient(cmap="summer")
# Out:
# <style type="text/css">
# #T_1f855_row0_col0, #T_1f855_row1_col1, #T_1f855_row2_col2, #T_1f855_row3_col3, #T_1f855_row4_col4, #T_1f855_row5_col5, #T_1f855_row6_col6 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_1f855_row0_col1 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_1f855_row0_col2 {
#   background-color: #79bc66;
#   color: #000000;
# }
# #T_1f855_row0_col3, #T_1f855_row3_col6 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_1f855_row0_col4 {
#   background-color: #309866;
#   color: #f1f1f1;
# }
# #T_1f855_row0_col5 {
#   background-color: #c1e066;
#   color: #000000;
# }
# #T_1f855_row0_col6 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_1f855_row1_col0 {
#   background-color: #8ec666;
#   color: #000000;
# }
# #T_1f855_row1_col2 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_1f855_row1_col3 {
#   background-color: #5bad66;
#   color: #f1f1f1;
# }
# #T_1f855_row1_col4 {
#   background-color: #209066;
#   color: #f1f1f1;
# }
# #T_1f855_row1_col5, #T_1f855_row6_col1, #T_1f855_row6_col2 {
#   background-color: #8cc666;
#   color: #000000;
# }
# #T_1f855_row1_col6 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_1f855_row2_col0 {
#   background-color: #5aac66;
#   color: #f1f1f1;
# }
# #T_1f855_row2_col1 {
#   background-color: #399c66;
#   color: #f1f1f1;
# }
# #T_1f855_row2_col3 {
#   background-color: #2f9766;
#   color: #f1f1f1;
# }
# #T_1f855_row2_col4, #T_1f855_row4_col0, #T_1f855_row4_col1, #T_1f855_row4_col2, #T_1f855_row4_col3, #T_1f855_row4_col5, #T_1f855_row4_col6 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_1f855_row2_col5 {
#   background-color: #4ea666;
#   color: #f1f1f1;
# }
# #T_1f855_row2_col6 {
#   background-color: #7abc66;
#   color: #000000;
# }
# #T_1f855_row3_col0 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_1f855_row3_col1 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_1f855_row3_col2 {
#   background-color: #4fa766;
#   color: #f1f1f1;
# }
# #T_1f855_row3_col4 {
#   background-color: #279366;
#   color: #f1f1f1;
# }
# #T_1f855_row3_col5, #T_1f855_row5_col1, #T_1f855_row5_col3 {
#   background-color: #8fc766;
#   color: #000000;
# }
# #T_1f855_row5_col0 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_1f855_row5_col2 {
#   background-color: #69b466;
#   color: #f1f1f1;
# }
# #T_1f855_row5_col4 {
#   background-color: #259266;
#   color: #f1f1f1;
# }
# #T_1f855_row5_col6, #T_1f855_row6_col5 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_1f855_row6_col0 {
#   background-color: #c2e066;
#   color: #000000;
# }
# #T_1f855_row6_col3 {
#   background-color: #a6d266;
#   color: #000000;
# }
# #T_1f855_row6_col4 {
#   background-color: #229066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1f855">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f855_level0_col0" class="col_heading level0 col0" >SOROS</th>
#       <th id="T_1f855_level0_col1" class="col_heading level0 col1" >PAULSON & CO</th>
#       <th id="T_1f855_level0_col2" class="col_heading level0 col2" >TIGER GLOBAL</th>
#       <th id="T_1f855_level0_col3" class="col_heading level0 col3" >BERK HATH</th>
#       <th id="T_1f855_level0_col4" class="col_heading level0 col4" >ALGO 1</th>
#       <th id="T_1f855_level0_col5" class="col_heading level0 col5" >ALGO 2</th>
#       <th id="T_1f855_level0_col6" class="col_heading level0 col6" >SP500</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f855_level0_row0" class="row_heading level0 row0" >SOROS</th>
#       <td id="T_1f855_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_1f855_row0_col1" class="data row0 col1" >0.699914</td>
#       <td id="T_1f855_row0_col2" class="data row0 col2" >0.561243</td>
#       <td id="T_1f855_row0_col3" class="data row0 col3" >0.754360</td>
#       <td id="T_1f855_row0_col4" class="data row0 col4" >0.321211</td>
#       <td id="T_1f855_row0_col5" class="data row0 col5" >0.826873</td>
#       <td id="T_1f855_row0_col6" class="data row0 col6" >0.837864</td>
#     </tr>
#     <tr>
#       <th id="T_1f855_level0_row1" class="row_heading level0 row1" >PAULSON & CO</th>
#       <td id="T_1f855_row1_col0" class="data row1 col0" >0.699914</td>
#       <td id="T_1f855_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_1f855_row1_col2" class="data row1 col2" >0.434479</td>
#       <td id="T_1f855_row1_col3" class="data row1 col3" >0.545623</td>
#       <td id="T_1f855_row1_col4" class="data row1 col4" >0.268840</td>
#       <td id="T_1f855_row1_col5" class="data row1 col5" >0.678152</td>
#       <td id="T_1f855_row1_col6" class="data row1 col6" >0.669732</td>
#     </tr>
#     <tr>
#       <th id="T_1f855_level0_row2" class="row_heading level0 row2" >TIGER GLOBAL</th>
#       <td id="T_1f855_row2_col0" class="data row2 col0" >0.561243</td>
#       <td id="T_1f855_row2_col1" class="data row2 col1" >0.434479</td>
#       <td id="T_1f855_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_1f855_row2_col3" class="data row2 col3" >0.424423</td>
#       <td id="T_1f855_row2_col4" class="data row2 col4" >0.164387</td>
#       <td id="T_1f855_row2_col5" class="data row2 col5" >0.507414</td>
#       <td id="T_1f855_row2_col6" class="data row2 col6" >0.623946</td>
#     </tr>
#     <tr>
#       <th id="T_1f855_level0_row3" class="row_heading level0 row3" >BERK HATH</th>
#       <td id="T_1f855_row3_col0" class="data row3 col0" >0.754360</td>
#       <td id="T_1f855_row3_col1" class="data row3 col1" >0.545623</td>
#       <td id="T_1f855_row3_col2" class="data row3 col2" >0.424423</td>
#       <td id="T_1f855_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_1f855_row3_col4" class="data row3 col4" >0.292033</td>
#       <td id="T_1f855_row3_col5" class="data row3 col5" >0.688082</td>
#       <td id="T_1f855_row3_col6" class="data row3 col6" >0.751371</td>
#     </tr>
#     <tr>
#       <th id="T_1f855_level0_row4" class="row_heading level0 row4" >ALGO 1</th>
#       <td id="T_1f855_row4_col0" class="data row4 col0" >0.321211</td>
#       <td id="T_1f855_row4_col1" class="data row4 col1" >0.268840</td>
#       <td id="T_1f855_row4_col2" class="data row4 col2" >0.164387</td>
#       <td id="T_1f855_row4_col3" class="data row4 col3" >0.292033</td>
#       <td id="T_1f855_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_1f855_row4_col5" class="data row4 col5" >0.287650</td>
#       <td id="T_1f855_row4_col6" class="data row4 col6" >0.278505</td>
#     </tr>
#     <tr>
#       <th id="T_1f855_level0_row5" class="row_heading level0 row5" >ALGO 2</th>
#       <td id="T_1f855_row5_col0" class="data row5 col0" >0.826873</td>
#       <td id="T_1f855_row5_col1" class="data row5 col1" >0.678152</td>
#       <td id="T_1f855_row5_col2" class="data row5 col2" >0.507414</td>
#       <td id="T_1f855_row5_col3" class="data row5 col3" >0.688082</td>
#       <td id="T_1f855_row5_col4" class="data row5 col4" >0.287650</td>
#       <td id="T_1f855_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_1f855_row5_col6" class="data row5 col6" >0.858753</td>
#     </tr>
#     <tr>
#       <th id="T_1f855_level0_row6" class="row_heading level0 row6" >SP500</th>
#       <td id="T_1f855_row6_col0" class="data row6 col0" >0.837864</td>
#       <td id="T_1f855_row6_col1" class="data row6 col1" >0.669732</td>
#       <td id="T_1f855_row6_col2" class="data row6 col2" >0.623946</td>
#       <td id="T_1f855_row6_col3" class="data row6 col3" >0.751371</td>
#       <td id="T_1f855_row6_col4" class="data row6 col4" >0.278505</td>
#       <td id="T_1f855_row6_col5" class="data row6 col5" >0.858753</td>
#       <td id="T_1f855_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500.
covariance = joined_data_columns["BERK HATH"].cov(joined_data_columns["SP500"])
variance_sp500 = joined_data_columns["SP500"].var()
rolling_covariance = joined_data_columns["BERK HATH"].rolling(window=60).cov(joined_data_columns["SP500"])
rolling_variance = joined_data_columns["SP500"].rolling(window=60).var()

rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(7,7))
# Out:
# <Axes: xlabel='Date'>

# %%
sharpe_ratio = joined_data_columns.mean()/joined_data_columns.std()
asr = sharpe_ratio*252**.5
asr
# Out:
# SOROS           0.356417
# PAULSON & CO   -0.483570
# TIGER GLOBAL   -0.121060
# BERK HATH       0.621810
# ALGO 1          1.360829
# ALGO 2          0.506929
# SP500           0.658706
# dtype: float64

# %%
asr.plot(kind="bar")
# Out:
# <Axes: >

# %%
# Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
print("Algo 1 outperformed SP 500 and Whale Return, Algo 2 did not")
# Out:
# Algo 1 outperformed SP 500 and Whale Return, Algo 2 did not

# %%
# Reading data from 1st stock & add symbol
costco = pd.read_csv("/Users/mihneaasandului/Downloads/cost_historical.csv", index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)

# Reading data from 2nd stock & add symbol
google = pd.read_csv("/Users/mihneaasandului/Downloads/goog_historical.csv", index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)

# Reading data from 3rd stock & add symbol
apple = pd.read_csv("/Users/mihneaasandului/Downloads/aapl_historical.csv", index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)

# Combine all stocks in a single DataFrame
stocks = pd.concat([costco,google,apple], axis="rows", join="inner")
stocks.head()
# Out:
# /var/folders/_7/z362cyrd65v3y2zk7bkxtnw80000gn/T/ipykernel_3173/1113112688.py:2: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   costco = pd.read_csv("/Users/mihneaasandului/Downloads/cost_historical.csv", index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
# /var/folders/_7/z362cyrd65v3y2zk7bkxtnw80000gn/T/ipykernel_3173/1113112688.py:5: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   google = pd.read_csv("/Users/mihneaasandului/Downloads/goog_historical.csv", index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
# /var/folders/_7/z362cyrd65v3y2zk7bkxtnw80000gn/T/ipykernel_3173/1113112688.py:8: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   apple = pd.read_csv("/Users/mihneaasandului/Downloads/aapl_historical.csv", index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62

# %%
 #Reset index
stocks = stocks.reset_index()

# %%
# Pivot tables
portfolio = stocks.pivot_table(values="NOCP", index="Trade DATE", columns= "Symbol")
portfolio.head()
# Out:
# Symbol        AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
# Calculate daily returns and drop NA's - dispaly sample data
daily_return = portfolio.pct_change()
daily_return.head()
daily_return.dropna().head()
# Out:
# Symbol          AAPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339

# %%
 # Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
portfolio_returns = daily_return.dot(weights)
portfolio_returns.pct_change()
portfolio_returns.dropna()
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
#                 ...
# 2019-05-03    0.013329
# 2019-05-06   -0.004557
# 2019-05-07   -0.018798
# 2019-05-08   -0.000547
# 2019-05-09   -0.001751
# Length: 249, dtype: float64

# %%
# Plot the data 
portfolio_returns.plot()
# Out:
# <Axes: xlabel='Trade DATE'>

# %%
 # Join your returns DataFrame to the original returns DataFrame
joined_data_columns["combined_df"] = portfolio_returns
joined_data_columns.dropna(inplace=True)
joined_data_columns.head()
# Out:
#                SOROS  PAULSON & CO  TIGER GLOBAL  BERK HATH    ALGO 1  \
# Date
# 2018-05-14  0.000000      0.000000      0.000000   0.000000  0.000915
# 2018-05-15 -0.000726     -0.001409     -0.003189  -0.014606 -0.001135
# 2018-05-16  0.008637      0.006244      0.005480   0.004310 -0.002326
# 2018-05-17 -0.001955      0.002524     -0.006267  -0.005140 -0.006949
# 2018-05-18 -0.004357     -0.002672     -0.012832  -0.002212  0.002557
#
#               ALGO 2     SP500  combined_df
# Date
# 2018-05-14  0.001635  0.000884     0.000015
# 2018-05-15 -0.001139 -0.006842    -0.010064
# 2018-05-16  0.003341  0.004061     0.009403
# 2018-05-17  0.005205 -0.000856    -0.001595
# 2018-05-18 -0.002496 -0.002632    -0.006061

# %%
# Calculate the Annualized Standard Deviation
daily_std = joined_data_columns.std()
annualized_std = daily_std * np.sqrt(252)
annualized_std.head()
# Out:
# SOROS           0.146675
# PAULSON & CO    0.116732
# TIGER GLOBAL    0.232531
# BERK HATH       0.247155
# ALGO 1          0.133704
# dtype: float64

# %%
# Calculate and plot rolling std with a 21-day window.
joined_data_columns.rolling(window=21).std().plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Date'>

# %%
#Calculate and plot the correlation
correlation_two = joined_data_columns.corr()
correlation_two
# Out:
#                  SOROS  PAULSON & CO  TIGER GLOBAL  BERK HATH    ALGO 1  \
# SOROS         1.000000      0.791962      0.478627   0.816675  0.337826
# PAULSON & CO  0.791962      1.000000      0.485375   0.650758  0.361301
# TIGER GLOBAL  0.478627      0.485375      1.000000   0.325457  0.114554
# BERK HATH     0.816675      0.650758      0.325457   1.000000  0.327000
# ALGO 1        0.337826      0.361301      0.114554   0.327000  1.000000
# ALGO 2        0.862846      0.783656      0.409496   0.782804  0.365512
# SP500         0.876981      0.766680      0.481030   0.852303  0.289358
# combined_df   0.733250      0.644210      0.391972   0.801158  0.261471
#
#                 ALGO 2     SP500  combined_df
# SOROS         0.862846  0.876981     0.733250
# PAULSON & CO  0.783656  0.766680     0.644210
# TIGER GLOBAL  0.409496  0.481030     0.391972
# BERK HATH     0.782804  0.852303     0.801158
# ALGO 1        0.365512  0.289358     0.261471
# ALGO 2        1.000000  0.875721     0.739936
# SP500         0.875721  1.000000     0.871875
# combined_df   0.739936  0.871875     1.000000

# %%
# Calculate and plot beta for your portfolio compared to the S&P 60 TSX.
covariance_mp = daily_return["AAPL"].cov(joined_data_columns["SP500"])                             
apple_beta = covariance_mp / variance_sp500
rolling_covariance = daily_return["AAPL"].rolling(window=60).cov(joined_data_columns["SP500"])
rolling_variance = joined_data_columns["SP500"].rolling(window=60).var()

rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(7,7))
# Out:
# <Axes: >

# %%
#Calculate the Sharpe ratios and generate a bar plot
sharpe_ratio = joined_data_columns.mean()/joined_data_columns.std()
asr = sharpe_ratio*252**.5
asr.plot(kind="bar")
# Out:
# <Axes: >

# %%
#How does your portfolio do?
print("My portfolio outperformed all portfolios except Algo 1 with a +1 return")
# Out:
# My portfolio outperformed all portfolios except Algo 1 with a +1 return
